# %% [markdown]
# <h1>Fusion - Anomaly Detection</h1>

# %%
import wget
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
print('downloading data')
data_url = 'https://api.thingspeak.com/channels/35939/feeds.csv?results=8000'
data_file = wget.download(data_url)
df = pd.read_csv(data_file)

def to_date(string):
    return datetime.datetime.strptime(string, '%Y-%m-%d %H:%M:%S UTC')

df.created_at = df.created_at.apply(to_date)
df.set_index('created_at', inplace=True)
print(df.shape)
df.head()
# Out:
# downloading data
# (8000, 5)
#                      entry_id  field1  field2  field3  field4
# created_at
# 2018-11-06 17:53:46    291413       0    35.8  27.062    24.5
# 2018-11-06 17:54:16    291414       0    35.8  27.062    24.5
# 2018-11-06 17:54:31    291415       0    36.3  27.062    24.5
# 2018-11-06 17:55:02    291416       0    36.9  27.125    24.5
# 2018-11-06 17:55:32    291417       0    35.8  27.125    24.5

# %%
plt.plot(df.field2,"c",df.field3,"r",df.field4,"b")
plt.show()

# %%
df3 = pd.DataFrame([])
df3['field2'] = df['field2'].resample('1T').mean()
df3['field3'] = df['field3'].resample('1T').mean()
df3['field4'] = df['field4'].resample('1T').mean()
df3.head()
# Out:
#                         field2   field3  field4
# created_at
# 2018-11-06 17:53:00  35.800000  27.0620    24.5
# 2018-11-06 17:54:00  36.050000  27.0620    24.5
# 2018-11-06 17:55:00  36.166667  27.1250    24.5
# 2018-11-06 17:56:00  35.800000  27.1870    24.5
# 2018-11-06 17:57:00  35.800000  27.2185    24.5

# %%
plt.plot(df3.field2,"c",df3.field3,"r",df3.field4,"b")
plt.show()

# %%
df3.to_pickle('feeds.pickle')

# %%
len_df = int(df3.shape[0]/3)
df_train = df3[:len_df]
df_test = df3[len_df:]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (1087, 3) (2176, 3)

# %%
def rmse(df1,df2):
    diff = (df1-df2) * (df1-df2)
    return diff.mean()**0.5
print("23",rmse(df_train['field2'],df_train['field3']))
print("24",rmse(df_train['field2'],df_train['field4']))
print("34",rmse(df_train['field3'],df_train['field4']))
print("43",rmse(df_train['field4'],df_train['field3']))
# Out:
# 23 8.761469087626669
# 24 10.041970010550747
# 34 1.5067779555770706
# 43 1.5067779555770706

# %%
num_layer = 5
num_val = 3

vec = []
xvec = []

for x in range(num_layer):
    vec.append([np.random.normal(0,.1) for _ in range(num_val)])
        
for x in range(num_val):
    xvec.append([np.random.normal(0,.1) for _ in range(num_layer)])
for x in vec:
    print("vec ",x)
for x in xvec:
    print("xvec ",x)   

for line in df_train.iterrows():
    layer = list(line[1])
    print("layer",layer)
    values=[0 for _ in range(num_layer)]
    print(values)
    for n in range(num_layer):
        print("n ",n)
        values[n] = 0
        for v in range(num_val):
            print("v ",v)
            values[n] += layer[v]*vec[v][n] 
    print("values",values)


    for i in xvec:
        print(i)
    
    break
# Out:
# vec  [-0.3630130027821022, -0.051047107731512234, 0.1663693724214261]
# vec  [0.009356541603289869, -0.04487467294230936, 0.12165270865891427]
# vec  [-0.018657557117347342, 0.03712426424818528, -0.07921869025398459]
# vec  [-0.050683387795780833, -0.24950049318229578, -0.14168115356640465]
# vec  [-0.09419131005818947, 0.10138018000787058, -0.20785356194864138]
# xvec  [0.002104183590420945, -0.07619962280750298, -0.006507103220935655, -0.014359495800191024, -0.030279812227338606]
# xvec  [0.10050529054037803, -0.12185815451304438, -0.0508402232683316, -0.13755400643140697, 0.09202980085160904]
# xvec  [0.015288125340871173, -0.08210167072180329, -0.09140618017527531, 0.17426924864575705, -0.013617176888058365]
# layer [35.8, 27.061999999999998, 24.5]
# [0, 0, 0, 0, 0]
# n  0
# v  0
# v  1
# v  2
# n  1
# v  0
# v  1
# v  2
# n  2
# v  0
# v  1
# v  2
# n  3
# v  0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-7a9826a9e533> in <module>
#      25         for v in range(num_val):
#      26             print("v ",v)
# ---> 27             values[n] += layer[v]*vec[v][n]
#      28     print("values",values)
#      29
#
# IndexError: list index out of range
